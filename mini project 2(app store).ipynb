# %%
import pandas as pd
filePath='Dataf/AppleStore.csv'
def readCsvData(filePath):
    return pd.read_csv(filePath)
df=readCsvData(filePath)
print (df)
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %% [markdown]
#  ## Probelm Statement
#    - Calculate the average rating of Gaming and Non-Gaming apps
#   - Price =0  - Free apps
#   - Price <20 - Affordable apps
#   - Price<50 - Expensive apps
#   -  Price >50 - Very expensive
#
#      - Description of the problem

# %%
data=df['user_rating'][df['prime_genre']=='Games'].mean()
data1=df["user_rating"][df['prime_genre']!='Games'].mean()
print("Avg rating gaming:{0:.2f}".format(data))
print("Avg rating nongaming:{0:.2f}".format(data1))
# Out:
# Avg rating gaming:3.69
# Avg rating nongaming:3.34

# %%
import matplotlib.pyplot as plt
free=len(df[df['price']==0])
aff=len(df[(df['price']<20) & (df['price']>0)])
exp=len(df[(df['price']<50) & (df['price']>=20)])
vexp=len(df[df['price']>100])  
price=['Free','Expensive','Affordable','Very Expensive']
li=[free,exp,aff,vexp]
plt.pie(li,labels = price,shadow=True,startangle=90,autopct='%1.2f%%')
plt.legend(loc='best')
plt.show()
